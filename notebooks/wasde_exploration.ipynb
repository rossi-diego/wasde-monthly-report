# %% [markdown]
# # WASDE Data Exploration

# %% [markdown]
# 1. Libraries and setup

# %%
# -- Setup environment and imports --

# Add 'src' directory to path to import project modules
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent / "src"))

# Load environment variables securely (e.g., WASDE_JWT)
from dotenv import load_dotenv
import os
load_dotenv()
my_token = os.getenv("WASDE_JWT")

# Core imports
from datetime import datetime
import pandas as pd

# Project configuration and functions
from config import RAW_DATA, PROCESSED_DATA
from wasde_downloader import fetch_wasde_releases, download_release_files, process_all_wasde_files, classify_crop_stage

# %% [markdown]
# 2. Identifying reports available and download of the csv/xml files

# %%
# Step 1: Fetch WASDE releases metadata using your secure token
releases = fetch_wasde_releases(token=my_token)
print(f"{len(releases)} releases found.")

# Step 2: Download the XML files (limit optional for testing)
download_release_files(releases, limit=10)
# Out:
# 316 releases found.

# %% [markdown]
# 3. Extracting supply demand data of the files: Wheat, corn, soybean, soybean meal and soybean oil

# %%
# Step 3: Process all downloaded WASDE files and load into a DataFrame
df_wasde = process_all_wasde_files()
df_wasde.head()
# Out:
# 181 XML files found in C:\Users\d1eg0\Desktop\python\Prediction\wasde\data\wasde_files
# 178 unique report dates found.
# Processing 2010-07-09_wasde-07-09-2010.xml...
#  → 214 rows extracted.
# Processing 2010-08-12_wasde-08-12-2010.xml...
#  → 214 rows extracted.
# Processing 2010-09-10_wasde-09-10-2010.xml...
#  → 214 rows extracted.
# Processing 2010-10-08_wasde-10-08-2010.xml...
#  → 214 rows extracted.
# Processing 2010-11-09_wasde-11-09-2010.xml...
#  → 214 rows extracted.
# Processing 2010-12-10_wasde-12-10-2010.xml...
#  → 214 rows extracted.
# Processing 2011-01-12_wasde-01-12-2011.xml...
#  → 214 rows extracted.
# Processing 2011-02-09_wasde-02-09-2011.xml...
#  → 214 rows extracted.
# Processing 2011-03-10_wasde-03-10-2011.xml...
#  → 214 rows extracted.
# Processing 2011-04-08_wasde-04-08-2011.xml...
#  → 214 rows extracted.
# Processing 2011-05-11_wasde-05-11-2011.xml...
#  → 214 rows extracted.
# Processing 2011-06-09_wasde-06-09-2011.xml...
#  → 214 rows extracted.
# Processing 2011-07-12_wasde-07-12-2011.xml...
#  → 214 rows extracted.
# Processing 2011-08-11_wasde-08-11-2011.xml...
#  → 214 rows extracted.
# Processing 2011-09-12_wasde-09-12-2011.xml...
#  → 214 rows extracted.
# Processing 2011-10-12_wasde-10-12-2011.xml...
#  → 214 rows extracted.
# Processing 2011-11-09_wasde-11-09-2011.xml...
#  → 214 rows extracted.
# Processing 2011-12-09_wasde-12-09-2011.xml...
#  → 214 rows extracted.
# Processing 2012-01-12_wasde-01-12-2012.xml...
#  → 214 rows extracted.
# Processing 2012-02-09_wasde-02-09-2012.xml...
#  → 214 rows extracted.
# Processing 2012-03-09_wasde-03-09-2012.xml...
#  → 214 rows extracted.
# Processing 2012-04-10_wasde-04-10-2012.xml...
#  → 214 rows extracted.
# Processing 2012-05-10_wasde-05-10-2012.xml...
#  → 214 rows extracted.
# Processing 2012-06-12_wasde-06-12-2012.xml...
#  → 214 rows extracted.
# Processing 2012-07-11_wasde-07-11-2012.xml...
#  → 214 rows extracted.
# Processing 2012-08-10_wasde-08-10-2012.xml...
#  → 214 rows extracted.
# Processing 2012-09-12_wasde-09-12-2012.xml...
#  → 214 rows extracted.
# Processing 2012-10-11_wasde-10-11-2012.xml...
#  → 214 rows extracted.
# Processing 2012-11-09_wasde-11-09-2012.xml...
#  → 214 rows extracted.
# Processing 2012-12-11_wasde-12-11-2012.xml...
#  → 214 rows extracted.
# Processing 2013-01-11_wasde-01-11-2013.xml...
#  → 214 rows extracted.
# Processing 2013-02-08_wasde-02-08-2013.xml...
#  → 214 rows extracted.
# Processing 2013-03-08_wasde-03-08-2013.xml...
#  → 214 rows extracted.
# Processing 2013-04-10_wasde-04-10-2013.xml...
#  → 214 rows extracted.
# Processing 2013-05-10_wasde-05-10-2013.xml...
#  → 217 rows extracted.
# Processing 2013-06-12_wasde-06-12-2013.xml...
#  → 217 rows extracted.
# Processing 2013-07-11_wasde-07-11-2013.xml...
#  → 217 rows extracted.
# Processing 2013-08-12_wasde-08-12-2013.xml...
#  → 217 rows extracted.
# Processing 2013-09-12_wasde-09-12-2013.xml...
#  → 217 rows extracted.
# Processing 2013-11-08_wasde-11-08-2013.xml...
#  → 217 rows extracted.
# Processing 2013-12-10_wasde-12-10-2013.xml...
#  → 217 rows extracted.
# Processing 2014-01-10_wasde-01-10-2014.xml...
#  → 217 rows extracted.
# Processing 2014-02-10_wasde-02-10-2014.xml...
#  → 217 rows extracted.
# Processing 2014-03-10_wasde-03-10-2014.xml...
#  → 217 rows extracted.
# Processing 2014-04-09_wasde-04-09-2014.xml...
#  → 217 rows extracted.
# Processing 2014-05-09_wasde-05-09-2014.xml...
#  → 217 rows extracted.
# Processing 2014-06-11_wasde-06-11-2014.xml...
#  → 217 rows extracted.
# Processing 2014-07-11_wasde-07-11-2014.xml...
#  → 217 rows extracted.
# Processing 2014-08-12_wasde-08-12-2014.xml...
#  → 217 rows extracted.
# Processing 2014-09-11_wasde-09-11-2014.xml...
#  → 217 rows extracted.
# Processing 2014-10-10_wasde-10-10-2014.xml...
#  → 217 rows extracted.
# Processing 2014-11-10_wasde-11-10-2014.xml...
#  → 217 rows extracted.
# Processing 2014-12-10_wasde-12-10-2014.xml...
#  → 217 rows extracted.
# Processing 2015-01-12_wasde-01-12-2015.xml...
#  → 217 rows extracted.
# Processing 2015-02-10_wasde-02-10-2015.xml...
#  → 217 rows extracted.
# Processing 2015-03-10_wasde-03-10-2015.xml...
#  → 217 rows extracted.
# Processing 2015-04-09_wasde-04-09-2015.xml...
#  → 217 rows extracted.
# Processing 2015-05-12_wasde-05-12-2015.xml...
#  → 217 rows extracted.
# Processing 2015-06-10_wasde-06-10-2015.xml...
#  → 217 rows extracted.
# Processing 2015-07-10_wasde-07-10-2015.xml...
#  → 217 rows extracted.
# Processing 2015-08-12_wasde-08-12-2015.xml...
#  → 215 rows extracted.
# Processing 2015-09-11_wasde-09-11-2015.xml...
#  → 215 rows extracted.
# Processing 2015-10-09_wasde-10-09-2015.xml...
#  → 215 rows extracted.
# Processing 2015-11-10_wasde-11-10-2015.xml...
#  → 215 rows extracted.
# Processing 2015-12-09_wasde-12-09-2015.xml...
#  → 215 rows extracted.
# Processing 2016-01-12_wasde-01-12-2016.xml...
#  → 215 rows extracted.
# Processing 2016-02-09_wasde-02-09-2016.xml...
#  → 215 rows extracted.
# Processing 2016-03-09_wasde-03-09-2016.xml...
#  → 215 rows extracted.
# Processing 2016-04-12_wasde-04-12-2016.xml...
#  → 215 rows extracted.
# Processing 2016-05-10_wasde-05-10-2016.xml...
#  → 215 rows extracted.
# Processing 2016-06-10_wasde-06-10-2016.xml...
#  → 215 rows extracted.
# Processing 2016-07-12_wasde-07-12-2016.xml...
#  → 215 rows extracted.
# Processing 2016-08-12_wasde-08-12-2016.xml...
#  → 215 rows extracted.
# Processing 2016-09-12_wasde-09-12-2016.xml...
#  → 215 rows extracted.
# Processing 2016-10-12_wasde-10-12-2016.xml...
#  → 215 rows extracted.
# Processing 2016-11-09_wasde-11-09-2016.xml...
#  → 215 rows extracted.
# Processing 2016-12-09_wasde-12-09-2016.xml...
#  → 215 rows extracted.
# Processing 2017-01-12_wasde-01-12-2017.xml...
#  → 215 rows extracted.
# Processing 2017-02-09_wasde-02-09-2017.xml...
#  → 215 rows extracted.
# Processing 2017-03-09_wasde-03-09-2017.xml...
#  → 215 rows extracted.
# Processing 2017-04-11_wasde-04-11-2017.xml...
#  → 215 rows extracted.
# Processing 2017-05-10_wasde-05-10-2017.xml...
#  → 215 rows extracted.
# Processing 2017-06-09_wasde-06-09-2017.xml...
#  → 215 rows extracted.
# Processing 2017-07-12_wasde-07-12-2017.xml...
#  → 215 rows extracted.
# Processing 2017-08-10_wasde-08-10-2017.xml...
#  → 215 rows extracted.
# Processing 2017-09-12_wasde-09-12-2017.xml...
#  → 215 rows extracted.
# Processing 2017-10-12_wasde-10-12-2017.xml...
#  → 215 rows extracted.
# Processing 2017-11-09_wasde-11-09-2017.xml...
#  → 215 rows extracted.
# Processing 2017-12-12_wasde-12-12-2017.xml...
#  → 215 rows extracted.
# Processing 2018-01-12_wasde-01-12-2018.xml...
#  → 215 rows extracted.
# Processing 2018-02-08_wasde-02-08-2018.xml...
#  → 215 rows extracted.
# Processing 2018-03-08_wasde-03-08-2018.xml...
#  → 215 rows extracted.
# Processing 2018-04-10_wasde-04-10-2018.xml...
#  → 215 rows extracted.
# Processing 2018-05-10_wasde-05-10-2018.xml...
#  → 215 rows extracted.
# Processing 2018-06-12_wasde-06-12-2018.xml...
#  → 215 rows extracted.
# Processing 2018-07-12_wasde-07-12-2018.xml...
#  → 215 rows extracted.
# Processing 2018-08-10_wasde-08-10-2018.xml...
#  → 215 rows extracted.
# Processing 2018-09-12_wasde-09-12-2018.xml...
#  → 215 rows extracted.
# Processing 2018-10-11_WASDE-582-October-11-2018.xml...
#  → 215 rows extracted.
# Processing 2018-11-08_latest.xml...
#  → 215 rows extracted.
# Processing 2018-12-11_latest.xml...
#  → 215 rows extracted.
# Processing 2018-12-14_latest.xml...
#  → 215 rows extracted.
# Processing 2019-02-08_latest.xml...
#  → 215 rows extracted.
# Processing 2019-03-08_latest.xml...
#  → 215 rows extracted.
# Processing 2019-04-09_latest.xml...
#  → 215 rows extracted.
# Processing 2019-05-10_wasde0519.xml...
#  → 236 rows extracted.
# Processing 2019-06-11_latest.xml...
#  → 236 rows extracted.
# Processing 2019-07-11_latest.xml...
#  → 236 rows extracted.
# Processing 2019-08-12_latest.xml...
#  → 236 rows extracted.
# Processing 2019-09-12_latest.xml...
#  → 236 rows extracted.
# Processing 2019-10-10_latest.xml...
#  → 236 rows extracted.
# Processing 2019-11-08_latest.xml...
#  → 236 rows extracted.
# Processing 2019-12-10_latest.xml...
#  → 236 rows extracted.
# Processing 2020-01-10_latest.xml...
#  → 236 rows extracted.
# Processing 2020-02-11_latest.xml...
#  → 236 rows extracted.
# Processing 2020-03-10_latest.xml...
#  → 236 rows extracted.
# Processing 2020-04-09_latest.xml...
#  → 236 rows extracted.
# Processing 2020-05-12_latest.xml...
#  → 236 rows extracted.
# Processing 2020-06-11_latest.xml...
#  → 236 rows extracted.
# Processing 2020-07-10_latest.xml...
#  → 236 rows extracted.
# Processing 2020-08-12_latest.xml...
#  → 236 rows extracted.
# Processing 2020-09-11_latest.xml...
#  → 236 rows extracted.
# Processing 2020-10-09_latest.xml...
#  → 236 rows extracted.
# Processing 2020-11-10_latest.xml...
#  → 236 rows extracted.
# Processing 2020-12-10_latest.xml...
#  → 236 rows extracted.
# Processing 2021-01-12_latest.xml...
#  → 236 rows extracted.
# Processing 2021-02-09_latest.xml...
#  → 236 rows extracted.
# Processing 2021-03-09_latest.xml...
#  → 236 rows extracted.
# Processing 2021-04-09_latest.xml...
#  → 236 rows extracted.
# Processing 2021-05-12_latest.xml...
#  → 242 rows extracted.
# Processing 2021-06-10_latest.xml...
#  → 242 rows extracted.
# Processing 2021-07-12_latest.xml...
#  → 242 rows extracted.
# Processing 2021-08-12_wasde0821.xml...
#  → 242 rows extracted.
# Processing 2021-09-10_wasde0921.xml...
#  → 242 rows extracted.
# Processing 2021-10-12_wasde1021.xml...
#  → 242 rows extracted.
# Processing 2021-11-09_wasde1121.xml...
#  → 242 rows extracted.
# Processing 2021-12-09_wasde1221.xml...
#  → 242 rows extracted.
# Processing 2022-01-12_wasde0122.xml...
#  → 242 rows extracted.
# Processing 2022-02-09_wasde0222.xml...
#  → 242 rows extracted.
# Processing 2022-03-09_wasde0322.xml...
#  → 242 rows extracted.
# Processing 2022-04-08_wasde0422.xml...
#  → 242 rows extracted.
# Processing 2022-05-12_wasde0522.xml...
#  → 240 rows extracted.
# Processing 2022-06-10_wasde0622.xml...
#  → 240 rows extracted.
# Processing 2022-07-12_wasde0722.xml...
#  → 240 rows extracted.
# Processing 2022-08-12_wasde0822.xml...
#  → 240 rows extracted.
# Processing 2022-09-12_wasde0922.xml...
#  → 240 rows extracted.
# Processing 2022-10-12_wasde1022.xml...
#  → 240 rows extracted.
# Processing 2022-11-09_wasde1122.xml...
#  → 240 rows extracted.
# Processing 2022-12-09_wasde1222.xml...
#  → 240 rows extracted.
# Processing 2023-01-12_wasde0123.xml...
#  → 240 rows extracted.
# Processing 2023-02-08_wasde0223.xml...
#  → 240 rows extracted.
# Processing 2023-03-08_wasde0323.xml...
#  → 240 rows extracted.
# Processing 2023-04-11_wasde0423.xml...
#  → 240 rows extracted.
# Processing 2023-05-12_wasde0523.xml...
#  → 240 rows extracted.
# Processing 2023-06-09_wasde0623.xml...
#  → 240 rows extracted.
# Processing 2023-07-12_wasde0723.xml...
#  → 240 rows extracted.
# Processing 2023-08-11_wasde0823.xml...
#  → 240 rows extracted.
# Processing 2023-09-12_wasde0923.xml...
#  → 240 rows extracted.
# Processing 2023-10-12_wasde1023.xml...
#  → 240 rows extracted.
# Processing 2023-11-09_wasde1123.xml...
#  → 240 rows extracted.
# Processing 2023-12-08_wasde1223.xml...
#  → 240 rows extracted.
# Processing 2024-01-12_wasde0124.xml...
#  → 240 rows extracted.
# Processing 2024-02-08_wasde0224.xml...
#  → 240 rows extracted.
# Processing 2024-03-08_wasde0324.xml...
#  → 240 rows extracted.
# Processing 2024-04-11_wasde0424.xml...
#  → 240 rows extracted.
# Processing 2024-05-10_wasde0524.xml...
#  → 240 rows extracted.
# Processing 2024-06-12_wasde0624.xml...
#  → 240 rows extracted.
# Processing 2024-07-12_wasde0724.xml...
#  → 240 rows extracted.
# Processing 2024-08-12_wasde0824.xml...
#  → 240 rows extracted.
# Processing 2024-09-12_wasde0924.xml...
#  → 240 rows extracted.
# Processing 2024-10-11_wasde1024.xml...
#  → 240 rows extracted.
# Processing 2024-11-08_wasde1124.xml...
#  → 240 rows extracted.
# Processing 2024-12-10_wasde1224v2.xml...
#  → 240 rows extracted.
# Processing 2025-01-10_wasde0125.xml...
#  → 240 rows extracted.
# Processing 2025-02-11_wasde0225.xml...
#  → 240 rows extracted.
# Processing 2025-03-11_wasde0325.xml...
#  → 240 rows extracted.
# Processing 2025-04-10_wasde0425v2.xml...
#  → 240 rows extracted.
# Processing 2025-05-12_wasde0525v2.xml...
#  → 240 rows extracted.
# CSV saved to: C:\Users\d1eg0\Desktop\python\Prediction\wasde\data\raw_data\wasde_commodities_timeseries.csv
#   report_date commodity              country marketing_year    crop_stage  \
# 0  2010-07-09     wheat            World  3/        2008/09  Current year
# 1  2010-07-09     wheat        United States        2008/09  Current year
# 2  2010-07-09     wheat        Total Foreign        2008/09  Current year
# 3  2010-07-09     wheat  Major Exporters  4/        2008/09  Current year
# 4  2010-07-09     wheat            Argentina        2008/09  Current year
#
#    Beginning Stocks  Production  Imports  Domestic Total 2  Exports  \
# 0            124.42      683.26   136.86            642.52   143.42
# 1              8.32       68.02     3.46             34.29    27.64
# 2            116.09      615.25   133.40            608.23   115.78
# 3             22.75      211.25     8.26            147.70    65.64
# 4              2.35       10.10     0.03              5.33     6.77
#
#    Ending Stocks  Domestic Crush  Domestic Feed
# 0         165.16             NaN            NaN
# 1          17.87             NaN            NaN
# 2         147.29             NaN            NaN
# 3          28.91             NaN            NaN
# 4           0.39             NaN            NaN

# %% [markdown]
# 4. Classifying the crop

# %%
    
if {"report_date", "marketing_year"}.issubset(df_wasde.columns):
    df_wasde["crop_stage"] = df_wasde.apply(
        lambda row: classify_crop_stage(str(row["marketing_year"]), str(row["report_date"])),
        axis=1
    )

# %% [markdown]
# 5. Checking dataframe info

# %%
print(df_wasde.head())
print("*"*60)
print(df_wasde.info())
# Out:
#   report_date commodity              country marketing_year    crop_stage  \
# 0  2010-07-09     wheat            World  3/        2008/09  Current year
# 1  2010-07-09     wheat        United States        2008/09  Current year
# 2  2010-07-09     wheat        Total Foreign        2008/09  Current year
# 3  2010-07-09     wheat  Major Exporters  4/        2008/09  Current year
# 4  2010-07-09     wheat            Argentina        2008/09  Current year
#
#    Beginning Stocks  Production  Imports  Domestic Total 2  Exports  \
# 0            124.42      683.26   136.86            642.52   143.42
# 1              8.32       68.02     3.46             34.29    27.64
# 2            116.09      615.25   133.40            608.23   115.78
# 3             22.75      211.25     8.26            147.70    65.64
# 4              2.35       10.10     0.03              5.33     6.77
#
#    Ending Stocks  Domestic Crush  Domestic Feed
# 0         165.16             NaN            NaN
# 1          17.87             NaN            NaN
# 2         147.29             NaN            NaN
# 3          28.91             NaN            NaN
# 4           0.39             NaN            NaN
# ************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40041 entries, 0 to 40040
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   report_date       40041 non-null  object
#  1   commodity         40041 non-null  object
#  2   country           40041 non-null  object
#  3   marketing_year    40041 non-null  object
#  4   crop_stage        40041 non-null  object
#  5   Beginning Stocks  39639 non-null  float64
#  6   Production        39639 non-null  float64
#  7   Imports           39639 non-null  float64
#  8   Domestic Total 2  23271 non-null  float64
#  9   Exports           39639 non-null  float64
#  10  Ending Stocks     40041 non-null  float64
#  11  Domestic Crush    2175 non-null   float64
#  12  Domestic Feed     19272 non-null  float64
# dtypes: float64(8), object(5)
# memory usage: 4.0+ MB
# None

# %% [markdown]
# 6. Exporting to csv to make the PowerBi visualization

# %%
df_wasde.to_csv(PROCESSED_DATA / "wasde_timeseries_clean.csv", index=False)
